# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding="latin-1")

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
df.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %%
df_data=df.isnull().sum()
df_data
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df.groupby('Item')['Item'].count()
# Out:
# Item
# Alcohol, Non-Food      283
# Alcoholic Beverages    564
# Animal Products        135
# Animal fats            639
# Apples and products    517
#                       ...
# Vegetables, Other      583
# Vegetal Products       135
# Wheat and products     653
# Wine                   497
# Yams                   383
# Name: Item, Length: 119, dtype: int64

# %%
df.groupby('Area')['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
df.groupby('Item')[['Y2015', 'Y2018']].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
df.groupby('Element')[['Y2014','Y2015','Y2016','Y2017','Y2018']].sum()
# Out:
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# Losses                                   153223.00   155439.00   157787.00
# Other uses (non-food)                     78718.13    66254.41    69563.68
# Processing                               282923.00   287929.00   280631.00
# ...

# %%
df.groupby('Element')[['Area','Y2015']].sum()
# Out:
#                                                                                      Area  \
# Element
# Domestic supply quantity                AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Export Quantity                         AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Fat supply quantity (g/capita/day)      AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Feed                                    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Food                                    AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Food supply (kcal/capita/day)           AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Food supply quantity (kg/capita/yr)     AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Import Quantity                         AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Losses                                  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# ...

# %%
madagascar_2015 = df[(df['Area'] == 'Madagascar') & (df['Y2015'] == 'Y2015')]

# %%
total_protein_supply = madagascar_2015['Protein supply quantity (g/capita/day)'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Protein supply quantity (g/capita/day)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
selected_columns = df[['Y2017', 'Area']]

# %%
grouped = selected_columns.groupby('Area').sum()

# %%
seventh_lowest = grouped.sort_values(by='Y2017').index[6]

# %%
print("Area with the 7th lowest sum in 2017:", seventh_lowest)
# Out:
# Area with the 7th lowest sum in 2017: Guinea-Bissau

# %%
unique_countries = df['Area'].unique()

# %%
total_unique_countries = len(unique_countries)

# %%
print("Total number of unique countries:", total_unique_countries)
# Out:
# Total number of unique countries: 49

# %%
data_2014 = df[df['Y2014'] == 'Y2014']

# %%
missing_data_2014 = data_2014.isnull().sum().sum()

# %%
total_data_2014 = data_2014.shape[0] * data_2014.shape[1]

# %%
percentage_missing_2014 = (missing_data_2014 / total_data_2014) * 100
# Out:
# <ipython-input-61-756dc3d8c28d>:1: RuntimeWarning: invalid value encountered in scalar divide
#   percentage_missing_2014 = (missing_data_2014 / total_data_2014) * 100

# %%
print("Total number of missing data in 2014:", missing_data_2014)
print("Percentage of missing data in 2014:", "{:.3f}%".format(percentage_missing_2014))
# Out:
# Total number of missing data in 2014: 0.0
# Percentage of missing data in 2014: nan%

# %%
columns_of_interest = ['Y2014', 'Y2015', 'Y2016', 'Y2017','Y2018']

# %%
df = pd.DataFrame({
    'Y2014': [1, 2, 3],
    'Y2015': [4, 5, 6],
    'Y2017': [7, 8, 9],
    'Y2018':[10,11,12]
  })

# %%
selected_columns = df[columns_of_interest]

print(selected_columns)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-5d20a4e7b414> in <cell line: 1>()
# ----> 1 selected_columns = df[columns_of_interest]
#       2
#       3 print(selected_columns)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# ...
